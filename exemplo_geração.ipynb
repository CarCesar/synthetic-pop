# %%
dom = '1600501_OIAPOQUE/Agregados_por_setores_caracteristicas_domicilio1_BR.csv'
malha ='1600501_OIAPOQUE/AP_setores_CD2022.shp'
cnefe = '1600501_OIAPOQUE/1600501_OIAPOQUE.csv'
demografia = '1600501_OIAPOQUE/Agregados_por_setores_demografia_BR_preenchido.csv'
alfabetizacao = '1600501_OIAPOQUE/Agregados_por_setores_alfabetizacao_BR.csv'
cor_raca = '1600501_OIAPOQUE/Agregados_por_setores_cor_ou_raca_BR.csv'
municipio = 'Oiapoque'

# %%
from SymPop import SyntheticPopulation

# %%
oiapoque = SyntheticPopulation(agg_demografia = demografia, agg_alfabetizacao = alfabetizacao, agg_cor = cor_raca, agg_domicilio = dom)

# %%
oiapoque.generate_population(municipio, malha, cnefe)

# %%
oiapoque.save_population(databasePath='dis.db', new_database=True)
